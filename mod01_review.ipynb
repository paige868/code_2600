# %% [markdown]
# ## Lab 1: Data in Python
#
# The data for this activity can be downloaded here (under "Data Sets"): https://www.statlearning.com/resources-python

# %% [markdown]
# As a first step, create a folder in this location called "data" and drop the Credit.csv file in that location.
#
# If you open the ".gitignore" file, you'll notice that one of the entries is "data" so that your data files will not be shared on GitHub.

# %% [markdown]
# ### What are the feature names?

# %% [markdown]
# Income,Limit,Rating,Cards,Age,Education,Own,Student,Married,Region,Balance

# %% [markdown]
# ### What are the data types of the feature values (i.e., numeric, categorical)

# %% [markdown]
# numeric, categorical, binary

# %% [markdown]
# ### Find the mean, median, and mode of the feature "Age."

# %%
import csv
import statistics


ages = []
with open('data/Credit.csv', 'r') as file:
    reader = csv.DictReader(file)
    for row in reader:
        ages.append(int(row['Age']))

mean = statistics.mean(ages)
# Out:
# 55.6675

# %%
import csv
import statistics

ages = []
with open('data/Credit.csv', 'r') as file:
    reader = csv.DictReader(file)
    for row in reader:
        ages.append(int(row['Age']))

median = statistics.median(ages)
# Out:
# 56.0

# %%
import csv
import statistics

ages = []
with open('data/Credit.csv', 'r') as file:
    reader = csv.DictReader(file)
    for row in reader:
        ages.append(int(row['Age']))

mode = statistics.mode(ages)

# %% [markdown]
# ### Create a subset of Credit that only contains the columns Age, Region, and Income. Call it "Subset."

# %%
import csv

Subset = []
cats = ["Age", "Region", "Income"]

with open('data/Credit.csv', 'r') as file:
    reader = csv.DictReader(file)
    for row in reader:
        picks = {key: row[key] for key in cats}
        Subset.append(picks)

# %% [markdown]
# ### From this subset, create two partitions:
# - One that contains records for Ages below 50, and one that contains Ages 50+
# - Call them "Younger" and "Older"

# %%
import csv
import statistics

Ages = []
Younger =[]
Older = []

with open('data/Credit.csv', 'r') as file:
    reader = csv.DictReader(file)
    for row in reader:
        Ages.append(int(row['Age']))

for age in Ages:
    if age < 50:
            Younger.append(age)
    else:
         Older.append(age)

# %% [markdown]
# ### Use these partitions to compare the mean and median Income for each age group (less than 50 vs. 50+)

# %%
total = 0

for i in Younger:
    total += i

mean_y = total/ len(Younger)
# Out:
# 38.06211180124224

# %%
total = 0

for i in Older:
    total += i

mean_y = total/ len(Older)
# Out:
# 67.52719665271967

# %%
median_y = statistics.median(Younger)
# Out:
# 39

# %%
median_o = statistics.median(Older)
# Out:
# 67

# %% [markdown]
# ### What does the difference between mean and median suggest about the distribution of income?

# %% [markdown]
# Type your answer here.

# %% [markdown]
# The median is slightly larger than the mean. This suggests that the data is scewed towards the right.

# %% [markdown]
# ### What are the possible values for Region?

# %% [markdown]
# west, east, south

# %% [markdown]
# ### Use the value_counts method to build a frequency table for the possible values of Region.

# %%
import pandas as pd

credit = pd.read_csv('data/Credit.csv')

region_counts = credit['Region'].value_counts()
# Out:
# Region
# South    199
# West     102
# East      99
# Name: count, dtype: int64

# %% [markdown]
# ### Compare the average income for students vs. non-students.

# %%
import csv
import statistics

student_income = []
non_income = []

with open('data/Credit.csv', 'r') as file:
    reader = csv.DictReader(file)
    for row in reader:
        if row["Student"] == 'Yes':
            student_income.append(float(row['Income']))
        else:
            non_income.append(float(row['Income']))

 
student_av = statistics.mean(student_income)
non_av = statistics.mean(non_income)
# Out:
# Average income of students:  47.29205
# Average income of non students:  44.988533333333336
# The income of students is more on average than non students

# %% [markdown]
# Often, banks will use a variable called _utilization_ to assess credit risk.
# Utilization is the ratio of balance to limit (i.e., what % of the credit limit is being used?)
# ### Add a feature to the Credit dataset to measure utilization

# %%
import csv

data_with_utilization = []

with open('data/Credit.csv', 'r') as file:
    reader = csv.DictReader(file)
    

    for row in reader:
        balance = float(row["Balance"])
        limit = float(row["Limit"])
        row['Utilization'] = balance/limit
        data_with_utilization.append(row)
# Out:
# [{'Income': '14.891', 'Limit': '3606', 'Rating': '283', 'Cards': '2', 'Age': '34', 'Education': '11', 'Own': 'No', 'Student': 'No', 'Married': 'Yes', 'Region': 'South', 'Balance': '333', 'Utilization': 0.09234608985024959}, {'Income': '106.025', 'Limit': '6645', 'Rating': '483', 'Cards': '3', 'Age': '82', 'Education': '15', 'Own': 'Yes', 'Student': 'Yes', 'Married': 'Yes', 'Region': 'West', 'Balance': '903', 'Utilization': 0.13589164785553048}, {'Income': '104.593', 'Limit': '7075', 'Rating': '514', 'Cards': '4', 'Age': '71', 'Education': '11', 'Own': 'No', 'Student': 'No', 'Married': 'No', 'Region': 'West', 'Balance': '580', 'Utilization': 0.08197879858657244}, {'Income': '148.924', 'Limit': '9504', 'Rating': '681', 'Cards': '3', 'Age': '36', 'Education': '11', 'Own': 'Yes', 'Student': 'No', 'Married': 'No', 'Region': 'West', 'Balance': '964', 'Utilization': 0.10143097643097643}, {'Income': '55.882', 'Limit': '4897', 'Rating': '357', 'Cards': '2', 'Age': '68', 'Education': '16', 'Own': 'No', 'Student': 'No', 'Married': 'Yes', 'Region': 'South', 'Balance': '331', 'Utilization': 0.0675924035123545}, {'Income': '80.18', 'Limit': '8047', 'Rating': '569', 'Cards': '4', 'Age': '77', 'Education': '10', 'Own': 'No', 'Student': 'No', 'Married': 'No', 'Region': 'South', 'Balance': '1151', 'Utilization': 0.1430346713060768}, {'Income': '20.996', 'Limit': '3388', 'Rating': '259', 'Cards': '2', 'Age': '37', 'Education': '12', 'Own': 'Yes', 'Student': 'No', 'Married': 'No', 'Region': 'East', 'Balance': '203', 'Utilization': 0.05991735537190083}, {'Income': '71.408', 'Limit': '7114', 'Rating': '512', 'Cards': '2', 'Age': '87', 'Education': '9', 'Own': 'No', 'Student': 'No', 'Married': 'No', 'Region': 'West', 'Balance': '872', 'Utilization': 0.12257520382344672}, {'Income': '15.125', 'Limit': '3300', 'Rating': '266', 'Cards': '5', 'Age': '66', 'Education': '13', 'Own': 'Yes', 'Student': 'No', 'Married': 'No', 'Region': 'South', 'Balance': '279', 'Utilization': 0.08454545454545455}, {'Income': '71.061', 'Limit': '6819', 'Rating': '491', 'Cards': '3', 'Age': '41', 'Education': '19', 'Own': 'Yes', 'Student': 'Yes', 'Married': 'Yes', 'Region': 'East', 'Balance': '1350', 'Utilization': 0.1979762428508579}, {'Income': '63.095', 'Limit': '8117', 'Rating': '589', 'Cards': '4', 'Age': '30', 'Education': '14', 'Own': 'No', 'Student': 'No', 'Married': 'Yes', 'Region': 'South', 'Balance': '1407', 'Utilization': 0.17333990390538376}, {'Income': '15.045', 'Limit': '1311', 'Rating': '138', 'Cards': '3', 'Age': '64', 'Education': '16', 'Own': 'No', 'Student': 'No', 'Married': 'No', 'Region': 'South', 'Balance': '0', 'Utilization': 0.0}, {'Income': '80.616', 'Limit': '5308', 'Rating': '394', 'Cards': '1', 'Age': '57', 'Education': '7', 'Own': 'Yes', 'Student': 'No', 'Married': 'Yes', 'Region': 'West', 'Balance': '204', 'Utilization': 0.03843255463451394}, {'Income': '43.682', 'Limit': '6922', 'Rating': '511', 'Cards': '1', 'Age': '49', 'Education': '9', 'Own': 'No', 'Student': 'No', 'Married': 'Yes', 'Region': 'South', 'Balance': '1081', 'Utilization': 0.15616873735914474}, {'Income': '19.144', 'Limit': '3291', 'Rating': '269', 'Cards': '2', 'Age': '75', 'Education': '13', 'Own': 'Yes', 'Student': 'No', 'Married': 'No', 'Region': 'East', 'Balance': '148', 'Utilization': 0.044971133394105134}, {'Income': '20.089', 'Limit': '2525', 'Rating': '200', 'Cards': '3', 'Age': '57', 'Education': '15', 'Own': 'Yes', 'Student': 'No', 'Married': 'Yes', 'Region': 'East', 'Balance': '0', 'Utilization': 0.0}, {'Income': '53.598', 'Limit': '3714', 'Rating': '286', 'Cards': '3', 'Age': '73', 'Education': '17', 'Own': 'Yes', 'Student': 'No', 'Married': 'Yes', 'Region': 'East', 'Balance': '0', 'Utilization': 0.0}, {'Income': '36.496', 'Limit': '4378', 'Rating': '339', 'Cards': '3', 'Age': '69', 'Education': '15', 'Own': 'Yes', 'Student': 'No', 'Married': 'Yes', 'Region': 'West', 'Balance': '368', 'Utilization': 0.08405664687071722}, {'Income': '49.57', 'Limit': '6384', 'Rating' ...

# %% [markdown]
# ### What is the maximum utilization value in this set?

# %%
max = 0
for row in data_with_utilization:
    ut = row["Utilization"]
   
    if ut > max:
        max = ut
# Out:
# 0.27693008426326576
